# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-3,3,100)#从-1到1生成100个点
y = 2*x + 1
plt.plot(x, y)
plt.show()

# %%
y1 = x**2
plt.figure(figsize=(2,2))#figsize参数用于调整图的大小
plt.plot(x,y1)

plt.figure()
plt.plot(x,y)

plt.show()

# %%
plt.plot(x, y, color='red', linewidth=1.0, linestyle='--')#color参数表示曲线的颜色，linewidth参数表示线的宽度，linestyle参数表示线的形式
plt.plot(x, y1, color='blue', linewidth=5.0, linestyle='-')
plt.show()

# %%
plt.xlim((-1,2))#限制x，y的范围
plt.ylim((-2,3))

plt.plot(x, y, color='red', linewidth=1.0, linestyle='--')#color参数表示曲线的颜色，linewidth参数表示线的宽度，linestyle参数表示线的形式
plt.plot(x, y1, color='blue', linewidth=5.0, linestyle='-')
plt.show()

# %%
plt.xlabel('I Am x')#添加坐标的描述
plt.ylabel('I Am y')

plt.plot(x, y, color='red', linewidth=1.0, linestyle='--')#color参数表示曲线的颜色，linewidth参数表示线的宽度，linestyle参数表示线的形式
plt.plot(x, y1, color='blue', linewidth=5.0, linestyle='-')
plt.show()

# %%
new_ticks = np.linspace(-2, 2, 11)
new_ticks
# Out:
# array([-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ])

# %%
#限制x，y的范围
plt.xlim((-1,2))
plt.ylim((-2,3))
#color参数表示曲线的颜色，linewidth参数表示线的宽度，linestyle参数表示线的形式
plt.plot(x, y, color='red', linewidth=1.0, linestyle='--')
plt.plot(x, y1, color='blue', linewidth=5.0, linestyle='-')
#更改坐标值或描述方式
plt.xticks(new_ticks)
plt.yticks([-1, 0, 1, 2, 3],
          ['level1','level2','level3','level4','level5'])
#获取边框
ax = plt.gca()
ax.spines['right'].set_color('none')#改变右边框的颜色
ax.spines['top'].set_color('none')#改变上边框的颜色

#把x轴的刻度设置为‘bottom'
#把y轴的刻度设置为‘left'
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
#设置bottom的对应到0点
#设置left的对应的到0点
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

plt.show()

# %%
plt.xlabel('I Am x')#添加坐标的描述
plt.ylabel('I Am y')

l1, = plt.plot(x, y, color='red', linewidth=1.0, linestyle='--')#color参数表示曲线的颜色，linewidth参数表示线的宽度，linestyle参数表示线的形式l
l2, = plt.plot(x, y1, color='blue', linewidth=5.0, linestyle='-')
#添加图例
plt.legend(handles=[l1,l2],labels=['test1','test2'],loc='best')

plt.show()

# %%
x = np.linspace(-3,3,100)
y = 2*x + 1

plt.plot(x, y, color='red', linewidth=1.0, linestyle='-')

ax = plt.gca()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))

x0 = 0.5
y0 = 2*x0 + 1
#画点
plt.scatter(x0,y0,s=50,color='blue')#参数s表示这个点大小
#画虚线
plt.plot([x0,x0],[y0,0],'k--')

plt.annotate(r'$2x+1=%s$' % y0,xy=(x0,y0),xytext=(+30,-30), textcoords='offset points',fontsize=16,
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'))

plt.text(-3,2, r'$this\ is\ the\ text$', fontdict={'size':'15','color':'r'})
plt.show()

# %%
plt.scatter(np.arange(5), np.arange(5))
plt.show()

# %%
x = np.random.normal(0, 1, 500)
y = np.random.normal(0, 1, 500)
#散点图
plt.scatter(x, y, s=50, c='b', alpha=0.5)
#去掉坐标值
plt.xticks(())
plt.yticks(())
plt.show()

# %%
x = np.arange(10)
y = 2**x + 10
#直方图
plt.bar(x, y,facecolor='#9999ff', edgecolor='white')
plt.show()

# %%
x = np.arange(10)
y = 2**x + 10
#直方图
plt.bar(x, y,facecolor='#9999ff', edgecolor='white')
for x,y in zip(x,y):
    plt.text(x,y, '%.2f' % y, ha='center', va='bottom')
plt.show()

# %%
x = np.linspace(-3,3,100)
y = np.linspace(-3,3,100)

def f(x,y):
    return (1-x / 2 + x**5 + y**3)*np.exp(-x**2-y**2)

X,Y = np.meshgrid(x,y)
#等高线
plt.contourf(X,Y,f(X,Y),8,alpha=0.75,cmap=plt.cm.hot)

C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)
plt.clabel(C, inline=True)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)

x = np.arange(-4, 4, 0.35)
y = np.arange(-4, 4, 0.35)
X,Y = np.meshgrid(x,y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)

x = np.arange(-4, 4, 0.35)
y = np.arange(-4, 4, 0.35)
X,Y = np.meshgrid(x,y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))
ax.contourf(X, Y, Z, zdir='z',offset=-1,cmap='rainbow')
plt.show()

# %% [markdown]
# 可借助ipython编译器，更详细、方便的观察3D图像

# %%
#在一张图中显示多张图片
plt.figure()
plt.subplot(2,2,1)
plt.plot([0,1],[0,1])

plt.subplot(2,2,2)
plt.plot([1,0],[0,1])

plt.subplot(2,2,3)
plt.plot([0,1],[1,0])

plt.subplot(2,2,4)
plt.plot([0,1],[0,1])

plt.show()

# %%
#在一张图中显示多张图片
plt.figure()
plt.subplot(2,1,1)
plt.plot([0,1],[0,1])

plt.subplot(2,3,4)
plt.plot([1,0],[0,1])

plt.subplot(2,3,5)
plt.plot([0,1],[1,0])

plt.subplot(2,3,6)
plt.plot([0,1],[1,0])


plt.show()

# %%
#动态作图
from matplotlib import animation

# %%
fig, ax = plt.subplots()

x = np.arange(0.2*np.pi,0.01)
line, = ax.plot(x, np.sin(x))

def animate(i):
    line.set_ydata(np.sin(x + i / 10))
    return line,

def init():
    line.set_ydata(np.sin(x))
    return line,

ani = animation.FuncAnimation(fig=fig, func=animate, init_func=init, interval=20)
plt.show()
